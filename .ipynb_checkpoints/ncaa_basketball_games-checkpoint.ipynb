# %% [markdown]
# # Notebook to make (currently) database of individual game pages from ESPN and also to obtain those pages not yet in hand.

# %% [raw]
# #import packages
# import numpy as np
# import pandas as pd
#
# import sys
# import os
# import time
# import re
# import urllib2
# import psycopg2
#
# from bs4 import BeautifulSoup
# from sqlalchemy import create_engine
# from sqlalchemy_utils import database_exists, create_database

# %%
def get_med_dir(year, month):
    
    if int(month) > 7:
        med_dir = str(year) + '-' + str(int(year)+1) + '/'
    else:
        med_dir = str(int(year)-1) + '-' + str(year) + '/'

    return med_dir

# %%
def start_games_db(dbname, username):
    print '  Firing up the data base.'
    
    engine = create_engine('postgres://%s@localhost/%s'%(username,dbname))
    print '    DB url:', engine.url
    db_exist = database_exists(engine.url)
    if not db_exist:
        create_database(engine.url)
    print '    DB exists? %s' % db_exist
    
    out_dict = {'dbname':dbname, 'username':username, 
                'exists':db_exist, 'engine_url':engine.url, 'engine':engine}
    
    return out_dict

# %%
def make_games_db(reset, dataframe, db_connect, boxscore_dict):
    
    #print reset
    #print dataframe
    #print db_connect
    #print boxscore_dict
    
    if reset == 1:
        my_if_exists = 'replace'
    else:
        my_if_exists = 'append'
    #print my_if_exists
    
    #print db_connect['engine']
    dataframe.to_sql(boxscore_dict['table'], db_connect['engine'], if_exists=my_if_exists)


    #sys.exit(0) 
    reset = 0 #now it will append instead of replacing
    return reset

# %%
def read_scoreboard(dir_file):
    
    target = open(dir_file, 'r')
    file_text = target.read()
    target.close()
    
    return file_text

# %%
def get_games_link(xscore_board):
    
    espn_links = []
    soup = BeautifulSoup(xscore_board, 'lxml')
    #finds = soup.find_all('a')

    finds = soup.find_all('script')
    for find in finds:
        try:
            text = find.get_text()
            match = re.search('window.espn.scoreboardData.*', text)
            if match is not None:
                found_it = match.group(0)
        except:
            a = 1
            
    #print found_it
    matches = re.findall('(http://espn.*?.com/.*?college.*?/.*?)\"\,', found_it)
    for match in matches:
        next_match = re.search('boxscore', match)
        if next_match is not None:
            espn_links.append(match)
            
    return espn_links

# %%
def games_db_query(my_con, scoreboard_table_name):
    print '    Now we query the table...'

# %%
def get_games_pages(xgames_link, my_con, xfile, xid, 
                    write=False, 
                    writedir=None, meddir=None):
#def get_yester_gamepage(yesterurl, my_con, udate, write=None, writedir=None):


    if writedir == None:
        writedir = 'boxscore_pages/'
    else:
        writedir = str(writedir)

    if meddir == None:
        meddir = ''
    else:
        meddir = str(meddir)
    
    
    headers = {'User-Agent':'Mozilla/5.0'}
    req = urllib2.Request(xgames_link, None, headers)
    #time.sleep(0.29)
    try:
        html = urllib2.urlopen(req).read()  #request the page
        soup = BeautifulSoup(html,'lxml')
        score_page = soup.prettify(encoding='utf-8')

        try:
            cur = my_con.cursor()
            cur.execute("UPDATE games SET in_hand=%s WHERE id=%s", ('yes', xid))  
            my_con.commit()
        except psycopg2.DatabaseError, e:
            if my_con:
                my_con.rollback()
            print 'Error %s' % e    
        find = 1
    except:
        find = 0

    if (write is True) and (find == 1):
        file_name = writedir + meddir + 'ncaa_mbb_boxscore_' + str(xid) + '.txt'
        #print file_name
        target = open(file_name, 'w')
        target.write(score_page)  #save to file
        target.close
        
    return find

# %%
def main(indir=None, remake_db=False, get_games=False):

    '''
    program to create the full games database from the full
    complement of available games.


    Data scraped from the scoreboard pages, after querying the 
    scoreboard database. 
    
    '''
    
    if indir is None:
        indir = 'scoreboard_pages/'
    else:
        indir = str(indir)
    dbname = 'ncaa_mbb_db'
    username = 'smaug'

    scoreboard_file = 'ncaa_mbb_scoreboard_full_YYYYMMDD.txt'

    boxscore_dir = 'boxscore_pages/'
    boxscore_file = 'ncaa_mbb_boxscore_DDDDDDDDD.txt'
    boxscore_table_name = 'games'
    boxscore_dict = {'dir':boxscore_dir, 'file':boxscore_file, 'table':boxscore_table_name}

    
    #start up Postgres db
    if remake_db:
        print '  Now remaking games database.'
        reset = 1 #do we append (0) or restart (1) the database
        cnt = 1 #silly database index counter since we give it one at a time
        scoreboard_table_name = 'scoreboard'
        db_connect = start_games_db(dbname, username)

        #connect to the database and query the scoreboard table
        con = None
        con = psycopg2.connect(database=dbname, user=username)

        sql_query = "SELECT date, year, month, day FROM %s WHERE in_hand='%s';" % (scoreboard_table_name, 'yes')
        #print sql_query
        try:
            dates_from_query = pd.read_sql_query(sql_query, con)
            #print dates_from_query
        except:
            print '  scoreboard_table does not exist' 

        for ii in np.arange(len(dates_from_query)):
            date_from_query = dates_from_query['date'][ii]
            date_from_query = date_from_query.replace('-', '')
            #print date_from_query
            
            med_dir = get_med_dir(dates_from_query['year'][ii], dates_from_query['month'][ii])
            file_to_check = indir + med_dir + scoreboard_file.replace('YYYYMMDD',date_from_query)
            print '    Checking file: %s.' % (file_to_check)
            
            file_text = read_scoreboard(file_to_check)
            #print len(file_text)
            game_links = get_games_link(file_text)
            print '      There were %i games on this day.' % (len(game_links))
            if len(game_links) != 0:
                for game_link in game_links:
                    game_id = re.search('(\d.*\d)', game_link)
                    
                    game_file = boxscore_dir + med_dir + boxscore_file.replace('DDDDDDDDD', game_id.group(1))
                    #print game_file
                    #print 'boxscore_pages/2002-2003/ncaa_mbb_boxscore_'
                    f = os.path.exists(game_file)
                    #help(f)
                    #print f
                    
                    if f:
                        #f.readlines()[0]
                        in_hand = 'yes'
                    else:
                        #print f.readlines()
                        in_hand = 'no'
                    #print in_hand
                    
                    my_dict = {'id':int(game_id.group(1)),
                              'date':dates_from_query['date'][ii], 
                              'year':dates_from_query['year'][ii], 
                              'month':dates_from_query['month'][ii],
                              'day':dates_from_query['day'][ii], 
                              'team1':'unknown',
                              'coach1':'unknown',
                              'team2':'unknown',
                              'coach2':'unknown',
                              'in_hand':in_hand, 
                              'url':game_link
                             }
                    my_df = pd.DataFrame(my_dict, index=[cnt])
                    #print my_df

                    #print '**********', reset
                    reset = make_games_db(reset, my_df, db_connect, boxscore_dict)
                    #print reset
                    cnt = cnt + 1

                    #if cnt >= 25:
                    #    sys.exit(0)
        
    if get_games:
        print '  Now retrieve individual game pages.'
        cnt = 1 #a counter to stop the for loop

        #connect to the database and query the scoreboard table
        print '    Connecting to the database...' 
        con = None
        con = psycopg2.connect(database=dbname, user=username)

        sql_query = "SELECT url, year, month, id FROM %s WHERE in_hand='%s';" % (boxscore_table_name, 'no')
        #print sql_query
        try:
            data_from_query = pd.read_sql_query(sql_query, con)
            print '    We still need %i game pages.' % (len(data_from_query))
        except:
            print '  games_table, games, does not exist' 
        print ''


        
        #print dates_from_query
        urls_from_query = data_from_query['url']
        for ii in np.arange(len(urls_from_query)):
            print '      Getting game: ', urls_from_query[ii]
            med_dir = get_med_dir(data_from_query['year'][ii], data_from_query['month'][ii])
            #print med_dir
            my_file = boxscore_file.replace('DDDDDDDDD', str(data_from_query['id'][ii]))
            #print my_file
            found = get_games_pages(urls_from_query[ii], con, 
                                    my_file, 
                                    data_from_query['id'][ii], 
                                    write=True, meddir=med_dir)
  
            cnt = cnt + 1
            if cnt >= 100000:
                sys.exit(0)

# %%
# boilerplate to execute call to main() function
if __name__ == '__main__':
    #main(remake_db=True)   
    main(remake_db=True, get_games=True)
# Out:
#   Now remaking games database.
#   Firing up the data base.
#     DB url: postgres://smaug@localhost/ncaa_mbb_db
#     DB exists? True
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021101.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021102.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021103.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021104.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021105.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021106.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021107.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021108.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021109.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021110.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021111.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021112.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021113.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021114.txt.
#       There were 2 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021115.txt.
#       There were 4 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021116.txt.
#       There were 3 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021117.txt.
#       There were 4 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021118.txt.
#       There were 11 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021119.txt.
#       There were 5 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021120.txt.
#       There were 2 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021121.txt.
#       There were 3 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021122.txt.
#       There were 86 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021123.txt.
#       There were 67 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021124.txt.
#       There were 45 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021125.txt.
#       There were 53 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021126.txt.
#       There were 67 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021127.txt.
#       There were 54 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021128.txt.
#       There were 5 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021129.txt.
#       There were 25 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021130.txt.
#       There were 109 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021201.txt.
#       There were 25 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021202.txt.
#       There were 44 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021203.txt.
#       There were 50 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021204.txt.
#       There were 53 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021205.txt.
#       There were 21 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021206.txt.
#       There were 18 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021207.txt.
#       There were 125 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021208.txt.
#       There were 16 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021209.txt.
#       There were 16 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021210.txt.
#       There were 29 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021211.txt.
#       There were 27 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021212.txt.
#       There were 11 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021213.txt.
#       There were 7 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021214.txt.
#       There were 103 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021215.txt.
#       There were 20 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021216.txt.
#       There were 19 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021217.txt.
#       There were 37 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021218.txt.
#       There were 39 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021219.txt.
#       There were 28 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021220.txt.
#       There were 29 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021221.txt.
#       There were 102 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021222.txt.
#       There were 32 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021223.txt.
#       There were 35 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021224.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021225.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021226.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021227.txt.
#       There were 25 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021228.txt.
#       There were 102 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021229.txt.
#       There were 33 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_20021230.txt.
#       There were 76 games on this day.
#     Checking file: scoreboard_pages/2002-2003/ncaa_mbb_scoreboard_full_
games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040212.txt.
#       There were 53 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040213.txt.
#       There were 10 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040214.txt.
#       There were 135 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040215.txt.
#       There were 13 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040216.txt.
#       There were 30 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040217.txt.
#       There were 12 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040218.txt.
#       There were 67 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040219.txt.
#       There were 41 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040220.txt.
#       There were 9 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040221.txt.
#       There were 137 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040222.txt.
#       There were 14 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040223.txt.
#       There were 26 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040224.txt.
#       There were 21 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040225.txt.
#       There were 52 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040226.txt.
#       There were 51 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040227.txt.
#       There were 10 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040228.txt.
#       There were 124 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040229.txt.
#       There were 27 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040301.txt.
#       There were 28 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040302.txt.
#       There were 21 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040303.txt.
#       There were 40 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040304.txt.
#       There were 27 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040305.txt.
#       There were 32 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040306.txt.
#       There were 101 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040307.txt.
#       There were 26 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040308.txt.
#       There were 18 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040309.txt.
#       There were 9 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040310.txt.
#       There were 20 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040311.txt.
#       There were 45 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040312.txt.
#       There were 36 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040313.txt.
#       There were 18 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040314.txt.
#       There were 5 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040315.txt.
#       There were 1 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040316.txt.
#       There were 4 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040317.txt.
#       There were 16 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040318.txt.
#       There were 16 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040319.txt.
#       There were 19 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040320.txt.
#       There were 10 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040321.txt.
#       There were 8 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040322.txt.
#       There were 4 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040323.txt.
#       There were 3 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040324.txt.
#       There were 2 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040325.txt.
#       There were 6 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040326.txt.
#       There were 4 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040327.txt.
#       There were 2 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040328.txt.
#       There were 2 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040329.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040330.txt.
#       There were 2 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040331.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040401.txt.
#       There were 1 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040402.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040403.txt.
#       There were 2 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040404.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040405.txt.
#       There were 1 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040406.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040407.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040408.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040409.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040410.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040411.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040412.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040413.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040414.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040415.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040416.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040417.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040418.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040419.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040420.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040421.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040422.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040423.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040424.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040425.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040426.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040427.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040428.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040429.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2003-2004/ncaa_mbb_scoreboard_full_20040430.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2004-2005/ncaa_mbb_scoreboard_full_20041101.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2004-2005/ncaa_mbb_scoreboard_full_20041102.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2004-2005/ncaa_mbb_scoreboard_full_20041103.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2004-2005/ncaa_mbb_scoreboard_full_20041104.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2004-2005/ncaa_mbb_scoreboard_full_20041105.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2004-2005/ncaa_mbb_scoreboard_full_20041106.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2004-2005/ncaa_mbb_scoreboard_full_20041107.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2004-2005/ncaa_mbb_scoreboard_full_20041108.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2004-2005/ncaa_mbb_scoreboard_full_20041109.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2004-2005/ncaa_mbb_scoreboard_full_20041110.txt.
#       There were 0 games on this day.
#     Checking file: scoreboard_pages/2004-2005/ncaa_mbb_scoreboard_full_20041111.txt.
#       There were 7 games on this day.
#     Checking file: scoreboard_pages/2004-2005/ncaa_mbb_scoreboard_full_20041112.txt.
#       There were 8 games on this day.
#     Checking file: scoreboard_pages/2004-2005/ncaa_mbb_scoreboard_full_20041113.txt.
#       There were 4 games on this day.
#     Checking file: scoreboard_pages/2004-2005/ncaa_mbb_scoreboard_full_20041114.txt.
#       There were 6 games on this day.
#     Checking file: scoreboard_pages/2004-2005/ncaa_mbb_scoreboard_full_20041115.txt.
